# %%
print("Hello World")
# Out:
# Hello World

# %%
with open("/Users/nishanali/Documents/output_scrapping/output_old.txt", "r") as handle:
    data = handle.read()

# %%
processed = data.split("\n\n")
processed = [x.split("\n") for x in processed]

# %%
processed[46]
# Out:
# ['Zip: 60033',
#  'Name: Elmbrook Veterinary Clinic and Grooming #WI07',
#  'Description: We offer one on one grooming in a calm environment located within a Veterinary Clinic.',
#  'Address: 150 N Janacek Rd, Brookfield, WI 53018 Waukesha',
#  'Website: http://Elmbrookvet.com',
#  'Phone number:  (262) 786-7616']

# %%
processed[46]
# Out:
# ['Zip: 20109',
#  'Name: Bark of the Town #MD18',
#  'Description: "30 yeaars experience',
#  'Luxury upscale salon grooming by appointment',
#  'Cat specialist"',
#  'Address: 305A Centennial Street, La Plata, Maryland 20646 United States',
#  'Website: ',
#  'Phone number:  (301) 392-9663']

# %%
proccesed_dict = dict()
proessed_list = list()

count = 0
for idx, _ in enumerate(processed):
    proessed_list.append({x.split(":")[0] : x.split(":")[1] for x in processed[idx]})
    count += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [18], in <cell line: 5>()
#       4 count = 0
#       5 for idx, _ in enumerate(processed):
# ----> 6     proessed_list.append({x.split(":")[0] : x.split(":")[1] for x in processed[idx]})
#       7     count += 1
#
# Input In [18], in <dictcomp>(.0)
#       4 count = 0
#       5 for idx, _ in enumerate(processed):
# ----> 6     proessed_list.append({x.split(":")[0] : x.split(":")[1] for x in processed[idx]})
#       7     count += 1
#
# IndexError: list index out of range

# %%
{x.split(":")[0] : x.split(":")[1] for x in processed[46]}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 {x.split(":")[0] : x.split(":")[1] for x in processed[46]}
#
# Input In [22], in <dictcomp>(.0)
# ----> 1 {x.split(":")[0] : x.split(":")[1] for x in processed[46]}
#
# IndexError: list index out of range

# %%
count
# Out:
# 2234

# %%
rcds = dict()
processed_list = list()
count = 0
for x in processed:
    count+=1
#     if count==47:
#         break
    key, val = None, None
    cont_flag = False
    for y in x:
        if ":" in y:
            key = y.split(":")[0].strip()
            val = y.split(":")[1].strip()
            if val ==" Bark of the Town #MD18":
                print(f"COUNT: {count}")
            
        else:
            if val:
                cont_flag = True
                val + str(y.strip())
        if not cont_flag:
            rcds[key] = val.strip() if val else val
    if cont_flag:
        rcds[key] = val.strip() if val else val
    processed_list.append(rcds.copy())

# %%
processed_list
# Out:
# [{'Zip': '24590',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24592',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24578',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24594',
#   'Name': 'Burlington Animal Hospital #D451',
#   'Description': 'I have been grooming dogs and cats at Burlington Animal Hospital for 15 years and grooming for a total of 21 years.',
#   'Address': '3496 Forestdale Drive, Burlington, NC 27215 USA',
#   'Website': 'http',
#   'Phone number': '(336) 584-9241'},
#  {'Zip': '24594',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24579',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24595',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24701',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24598',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24599',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24586',
#   'Name': 'Burlington Animal Hospital #D451',
#   'Description': 'I have been grooming dogs and cats at Burlington Animal Hospital for 15 years and grooming for a total of 21 years.',
#   'Address': '3496 Forestdale Drive, Burlington, NC 27215 USA',
#   'Website': 'http',
#   'Phone number': '(336) 584-9241'},
#  {'Zip': '24586',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24605',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24590',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24592',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24712',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24609',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24594',
#   'Name': 'Burlington Animal Hospital #D451',
#   'Description': 'I have been grooming dogs and cats at Burlington Animal Hospital for 15 years and grooming for a total of 21 years.',
#   'Address': '3496 Forestdale Drive, Burlington, NC 27215 USA',
#   'Website': 'http',
#   'Phone number': '(336) 584-9241'},
#  {'Zip': '24594',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24595',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24598',
#   'Name': 'Pam’s Paw Prints #N541',
#   'Description': 'We are a small, personal salon offering all breed grooming and specializing in individual styles for every little body! With 35 years of experience, I especially enjoy finding the “special” in every dog so we can come up with the perfect clip that will fit his or her personality. Our clients are our grooming family and we want them to feel at home.... grooming is all we do and we like it that way!',
#   'Address': '2919 Guess Rd, Durham,, NC 27572 USA',
#   'Website': '',
#   'Phone number': '(919) 471-4729'},
#  {'Zip': '24599',
#   'Name': "Gina's Pet Grooming LLC. #D492",
#   'Description': 'Small grooming salon.  All breeds accepted.  Rabbits, Cats, Guinea Pigs accepted as well.  18 years in the grooming industry.',
#   'Address': '2458 Jefferson Hwy.  Suit 103, Waynesboro, VA 22980 United States',
#   'Website': '',
#   'Phone number': '(540) 414-2592'},
#  {'Zip': '24614',
#   'Name': 'Far Fetched Grooming & Boarding #C567',
#   'Description': 'WELCOME TO FAR FETCHED GROOMING! We are a full service pet groom shop located in beautiful Big Stone Gap, Virginia. We are dedicated to our furry friends and will go to any length to ensure they leave their visit with tails wagging!',
#   'Address': '1 Cloverleaf Square, Suite D1, Big Stone Gap, VA 24219 United States',
#   'Website': 'http',
#   'Phone number': '(276) 393-3824'},
#  {'Zip': '24605',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24609',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24614',
#   'Name': 'Far Fetched Grooming & Boarding #C567',
#   'Description': 'WELCOME TO FAR FETCHED GROOMING! We are a full service pet groom shop located in beautiful Big Stone Gap, Virginia. We are dedicated to our furry friends and will go to any length to ensure they leave their visit with tails wagging!',
#   'Address': '1 Cloverleaf Square, Suite D1, Big Stone Gap, VA 24219 United States',
#   'Website': 'http',
#   'Phone number': '(276) 393-3824'},
#  {'Zip': '24630',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24739',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24740',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24637',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24639',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24641',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24630',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24637',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24651',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24639',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24641',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '24656',
#   'Name': 'Far Fetched Grooming & Boarding #C567',
#   'Description': 'WELCOME TO FAR FETCHED GROOMING! We are a full service pet groom shop located in beautiful Big Stone Gap, Virginia. We are dedicated to our furry friends and will go to any length to ensure they leave their visit with tails wagging!',
#   'Address': '1 Cloverleaf Square, Suite D1, Big Stone Gap, VA 24219 United States',
#   'Website': 'http',
#   'Phone number': '(276) 393-3824'},
#  {'Zip': '24651',
#   'Name': 'Creative K-9 Designs #VA162',
#   'Description': 'We are a low anxiety, All-Breed salon, featuring services such as',
#   'Address': '935 S. 4 1/2 St., Wytheville, Va 24382 United States',
#   'Website': '',
#   'Phone number': '(276) 613-0770'},
#  {'Zip': '20109',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20109',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20109',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20109',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20109',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20109',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20109',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20109',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20109',
#   'Name': 'Wash N Wag of Culpeper #VA002',
#   'Description': '',
#   'Address': '217 Southgate Shopping Center, Spotsylviana, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 829-6665'},
#  {'Zip': '20109',
#   'Name': 'Canine Clippers School of Pet Grooming #VA002',
#   'Description': '',
#   'Address': '219 Southgate Shopping Center, Culpeper, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 825-5959'},
#  {'Zip': '20109',
#   'Name': 'Sensational Canines, LLC #VA122',
#   'Description': 'We are a small salon focusing on personalized care for your dog.  I am a certified master groomer with over 20 years of experience.  We specialize in curly coats, scissoring, and hand stripping.',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(703) 727-1452'},
#  {'Zip': '20109',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20109',
#   'Name': 'Bella Rose Grooming Studio #D931',
#   'Description': 'Bella Rose Grooming Studio offers full service dog grooming in the Old Town area of Winchester,Virginia. I offer stress free grooming experience for your precious fur babies. I use the highest quality of products and focus on coat quality and condition of the skin. My ultimate goal is to provide excellent customer service, a safe environment and high quality grooming.',
#   'Address': '220 Millwood Avenue, Winchester, VA 22601 USA',
#   'Website': 'https',
#   'Phone number': '(540) 504-7383'},
#  {'Zip': '20109',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '24656',
#   'Name': 'Far Fetched Grooming & Boarding #C567',
#   'Description': 'WELCOME TO FAR FETCHED GROOMING! We are a full service pet groom shop located in beautiful Big Stone Gap, Virginia. We are dedicated to our furry friends and will go to any length to ensure they leave their visit with tails wagging!',
#   'Address': '1 Cloverleaf Square, Suite D1, Big Stone Gap, VA 24219 United States',
#   'Website': 'http',
#   'Phone number': '(276) 393-3824'},
#  {'Zip': '20120',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20120',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20120',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20120',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20120',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20120',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20120',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20120',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20120',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20120',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20120',
#   'Name': 'Canine Clippers School of Pet Grooming #VA002',
#   'Description': '',
#   'Address': '219 Southgate Shopping Center, Culpeper, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 825-5959'},
#  {'Zip': '20120',
#   'Name': 'Wash N Wag of Culpeper #VA002',
#   'Description': '',
#   'Address': '217 Southgate Shopping Center, Spotsylviana, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 829-6665'},
#  {'Zip': '20120',
#   'Name': 'Sensational Canines, LLC #VA122',
#   'Description': 'We are a small salon focusing on personalized care for your dog.  I am a certified master groomer with over 20 years of experience.  We specialize in curly coats, scissoring, and hand stripping.',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(703) 727-1452'},
#  {'Zip': '20120',
#   'Name': 'Bella Rose Grooming Studio #D931',
#   'Description': 'Bella Rose Grooming Studio offers full service dog grooming in the Old Town area of Winchester,Virginia. I offer stress free grooming experience for your precious fur babies. I use the highest quality of products and focus on coat quality and condition of the skin. My ultimate goal is to provide excellent customer service, a safe environment and high quality grooming.',
#   'Address': '220 Millwood Avenue, Winchester, VA 22601 USA',
#   'Website': 'https',
#   'Phone number': '(540) 504-7383'},
#  {'Zip': '20120',
#   'Name': 'Petsmart #MD37',
#   'Description': 'I have been grooming for 18 years and I love what I do.  I am always looking for opportunities to learn new techniques and expand my knowledge.',
#   'Address': '2601 Housley Rd, Annapolis, Maryland 21401 United States',
#   'Website': '',
#   'Phone number': '(410) 571-8646'},
#  {'Zip': '20120',
#   'Name': 'It’s a Pet Thing LLC #A966',
#   'Description': 'I have been grooming since 2014 and award winning competitive groomer since 2020. I take continuing education classes monthly and hold several certifications.',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(410) 544-5533'},
#  {'Zip': '20109',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20109',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20109',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20109',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20109',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20109',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20109',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20109',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20109',
#   'Name': 'Wash N Wag of Culpeper #VA002',
#   'Description': '',
#   'Address': '217 Southgate Shopping Center, Spotsylviana, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 829-6665'},
#  {'Zip': '20109',
#   'Name': 'Canine Clippers School of Pet Grooming #VA002',
#   'Description': '',
#   'Address': '219 Southgate Shopping Center, Culpeper, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 825-5959'},
#  {'Zip': '20109',
#   'Name': 'Sensational Canines, LLC #VA122',
#   'Description': 'We are a small salon focusing on personalized care for your dog.  I am a certified master groomer with over 20 years of experience.  We specialize in curly coats, scissoring, and hand stripping.',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(703) 727-1452'},
#  {'Zip': '20109',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20109',
#   'Name': 'Bella Rose Grooming Studio #D931',
#   'Description': 'Bella Rose Grooming Studio offers full service dog grooming in the Old Town area of Winchester,Virginia. I offer stress free grooming experience for your precious fur babies. I use the highest quality of products and focus on coat quality and condition of the skin. My ultimate goal is to provide excellent customer service, a safe environment and high quality grooming.',
#   'Address': '220 Millwood Avenue, Winchester, VA 22601 USA',
#   'Website': 'https',
#   'Phone number': '(540) 504-7383'},
#  {'Zip': '20109',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20120',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20120',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20120',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20120',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20120',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20120',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20120',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20120',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20120',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20120',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20120',
#   'Name': 'Canine Clippers School of Pet Grooming #VA002',
#   'Description': '',
#   'Address': '219 Southgate Shopping Center, Culpeper, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 825-5959'},
#  {'Zip': '20120',
#   'Name': 'Wash N Wag of Culpeper #VA002',
#   'Description': '',
#   'Address': '217 Southgate Shopping Center, Spotsylviana, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 829-6665'},
#  {'Zip': '20120',
#   'Name': 'Sensational Canines, LLC #VA122',
#   'Description': 'We are a small salon focusing on personalized care for your dog.  I am a certified master groomer with over 20 years of experience.  We specialize in curly coats, scissoring, and hand stripping.',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(703) 727-1452'},
#  {'Zip': '20120',
#   'Name': 'Bella Rose Grooming Studio #D931',
#   'Description': 'Bella Rose Grooming Studio offers full service dog grooming in the Old Town area of Winchester,Virginia. I offer stress free grooming experience for your precious fur babies. I use the highest quality of products and focus on coat quality and condition of the skin. My ultimate goal is to provide excellent customer service, a safe environment and high quality grooming.',
#   'Address': '220 Millwood Avenue, Winchester, VA 22601 USA',
#   'Website': 'https',
#   'Phone number': '(540) 504-7383'},
#  {'Zip': '20120',
#   'Name': 'Petsmart #MD37',
#   'Description': 'I have been grooming for 18 years and I love what I do.  I am always looking for opportunities to learn new techniques and expand my knowledge.',
#   'Address': '2601 Housley Rd, Annapolis, Maryland 21401 United States',
#   'Website': '',
#   'Phone number': '(410) 571-8646'},
#  {'Zip': '20120',
#   'Name': 'It’s a Pet Thing LLC #A966',
#   'Description': 'I have been grooming since 2014 and award winning competitive groomer since 2020. I take continuing education classes monthly and hold several certifications.',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(410) 544-5533'},
#  {'Zip': '20147',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20147',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20147',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20147',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20147',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20147',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20147',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20147',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20147',
#   'Name': 'Sensational Canines, LLC #VA122',
#   'Description': 'We are a small salon focusing on personalized care for your dog.  I am a certified master groomer with over 20 years of experience.  We specialize in curly coats, scissoring, and hand stripping.',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(703) 727-1452'},
#  {'Zip': '20147',
#   'Name': 'Bella Rose Grooming Studio #D931',
#   'Description': 'Bella Rose Grooming Studio offers full service dog grooming in the Old Town area of Winchester,Virginia. I offer stress free grooming experience for your precious fur babies. I use the highest quality of products and focus on coat quality and condition of the skin. My ultimate goal is to provide excellent customer service, a safe environment and high quality grooming.',
#   'Address': '220 Millwood Avenue, Winchester, VA 22601 USA',
#   'Website': 'https',
#   'Phone number': '(540) 504-7383'},
#  {'Zip': '20147',
#   'Name': 'Grooming Van-Go #WV10',
#   'Description': 'Grooming Van-Go offers luxury mobile spa services. We are Iv San Bernard exclusive, offering many forms of skin relief therapies, coat growth therapies, and traditional spa soaks that every pet can enjoy. Not only will our NDGAA certified groomer make your pet look better, but they’ll FEEL better too!  So, sit, stay, and we’ll roll over to you.',
#   'Address': '333 Pendleton Dr, Martinsburg, WV 25401 United States',
#   'Website': 'http',
#   'Phone number': '(304) 804-7297'},
#  {'Zip': '20147',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20147',
#   'Name': "Poodles! / Puttin' on the Dog, Inc. #MD11",
#   'Description': 'National Certified Master Groomer with over 40 years experience providing limited mobile service for mannerly PUREBRED toy and miniature poodles (25 pound limit) in the Westminster, Md. area. Text ONLY 443-520-1721',
#   'Address': '1130 Old Westminster Rd, Westminster, MARYLAND (MD) 21157 United States of America',
#   'Website': '',
#   'Phone number': '(443) 520-1721'},
#  {'Zip': '20147',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '1130 Old Westminster Rd, Westminster, MARYLAND (MD) 21157 United States of America',
#   'Website': '',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20147',
#   'Name': 'Barnwellness Animal Care #A170',
#   'Description': 'A warm and cozy home grooming salon Servicing all breeds and sizes.',
#   'Address': '716 cloudyfold drive, Barnwellness Animal Care, Pikesville, MD 21208 United States',
#   'Website': 'http',
#   'Phone number': '(410) 269-3019'},
#  {'Zip': '20147',
#   'Name': 'Wash N Wag of Culpeper #VA002',
#   'Description': '',
#   'Address': '217 Southgate Shopping Center, Spotsylviana, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 829-6665'},
#  {'Zip': '20147',
#   'Name': 'Canine Clippers School of Pet Grooming #VA002',
#   'Description': '',
#   'Address': '219 Southgate Shopping Center, Culpeper, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 825-5959'},
#  {'Zip': '20147',
#   'Name': 'It’s a Pet Thing LLC #A966',
#   'Description': 'I have been grooming since 2014 and award winning competitive groomer since 2020. I take continuing education classes monthly and hold several certifications.',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(410) 544-5533'},
#  {'Zip': '20148',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20148',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20148',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20148',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20148',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20148',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20148',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20148',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20148',
#   'Name': 'Sensational Canines, LLC #VA122',
#   'Description': 'We are a small salon focusing on personalized care for your dog.  I am a certified master groomer with over 20 years of experience.  We specialize in curly coats, scissoring, and hand stripping.',
#   'Address': '206 Wrights Run Lane, White Post, VA 22663 United States',
#   'Website': 'http',
#   'Phone number': '(703) 727-1452'},
#  {'Zip': '20148',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20148',
#   'Name': 'Bella Rose Grooming Studio #D931',
#   'Description': 'Bella Rose Grooming Studio offers full service dog grooming in the Old Town area of Winchester,Virginia. I offer stress free grooming experience for your precious fur babies. I use the highest quality of products and focus on coat quality and condition of the skin. My ultimate goal is to provide excellent customer service, a safe environment and high quality grooming.',
#   'Address': '220 Millwood Avenue, Winchester, VA 22601 USA',
#   'Website': 'https',
#   'Phone number': '(540) 504-7383'},
#  {'Zip': '20148',
#   'Name': 'Grooming Van-Go #WV10',
#   'Description': 'Grooming Van-Go offers luxury mobile spa services. We are Iv San Bernard exclusive, offering many forms of skin relief therapies, coat growth therapies, and traditional spa soaks that every pet can enjoy. Not only will our NDGAA certified groomer make your pet look better, but they’ll FEEL better too!  So, sit, stay, and we’ll roll over to you.',
#   'Address': '333 Pendleton Dr, Martinsburg, WV 25401 United States',
#   'Website': 'http',
#   'Phone number': '(304) 804-7297'},
#  {'Zip': '20148',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '333 Pendleton Dr, Martinsburg, WV 25401 United States',
#   'Website': 'http',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20148',
#   'Name': 'Wash N Wag of Culpeper #VA002',
#   'Description': '',
#   'Address': '217 Southgate Shopping Center, Spotsylviana, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 829-6665'},
#  {'Zip': '20148',
#   'Name': 'Canine Clippers School of Pet Grooming #VA002',
#   'Description': '',
#   'Address': '219 Southgate Shopping Center, Culpeper, US 22701 USA',
#   'Website': 'http',
#   'Phone number': '(540) 825-5959'},
#  {'Zip': '20148',
#   'Name': "Poodles! / Puttin' on the Dog, Inc. #MD11",
#   'Description': 'National Certified Master Groomer with over 40 years experience providing limited mobile service for mannerly PUREBRED toy and miniature poodles (25 pound limit) in the Westminster, Md. area. Text ONLY 443-520-1721',
#   'Address': '1130 Old Westminster Rd, Westminster, MARYLAND (MD) 21157 United States of America',
#   'Website': '',
#   'Phone number': '(443) 520-1721'},
#  {'Zip': '20148',
#   'Name': 'Barnwellness Animal Care #A170',
#   'Description': 'A warm and cozy home grooming salon Servicing all breeds and sizes.',
#   'Address': '716 cloudyfold drive, Barnwellness Animal Care, Pikesville, MD 21208 United States',
#   'Website': 'http',
#   'Phone number': '(410) 269-3019'},
#  {'Zip': '20147',
# ...
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20408',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20408',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20408',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20408',
#   'Name': 'Petsmart #MD37',
#   'Description': 'I have been grooming for 18 years and I love what I do.  I am always looking for opportunities to learn new techniques and expand my knowledge.',
#   'Address': '2601 Housley Rd, Annapolis, Maryland 21401 United States',
#   'Website': '',
#   'Phone number': '(410) 571-8646'},
#  {'Zip': '20408',
#   'Name': 'It’s a Pet Thing LLC #A966',
#   'Description': 'I have been grooming since 2014 and award winning competitive groomer since 2020. I take continuing education classes monthly and hold several certifications.',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(410) 544-5533'},
#  {'Zip': '20408',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20408',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20408',
#   'Name': 'Barnwellness Animal Care #A170',
#   'Description': 'A warm and cozy home grooming salon Servicing all breeds and sizes.',
#   'Address': '716 cloudyfold drive, Barnwellness Animal Care, Pikesville, MD 21208 United States',
#   'Website': 'http',
#   'Phone number': '(410) 269-3019'},
#  {'Zip': '20408',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20408',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20408',
#   'Name': "Poodles! / Puttin' on the Dog, Inc. #MD11",
#   'Description': 'National Certified Master Groomer with over 40 years experience providing limited mobile service for mannerly PUREBRED toy and miniature poodles (25 pound limit) in the Westminster, Md. area. Text ONLY 443-520-1721',
#   'Address': '1130 Old Westminster Rd, Westminster, MARYLAND (MD) 21157 United States of America',
#   'Website': '',
#   'Phone number': '(443) 520-1721'},
#  {'Zip': '20418',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20418',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20418',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20418',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20418',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20418',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20418',
#   'Name': 'Petsmart #MD37',
#   'Description': 'I have been grooming for 18 years and I love what I do.  I am always looking for opportunities to learn new techniques and expand my knowledge.',
#   'Address': '2601 Housley Rd, Annapolis, Maryland 21401 United States',
#   'Website': '',
#   'Phone number': '(410) 571-8646'},
#  {'Zip': '20418',
#   'Name': 'It’s a Pet Thing LLC #A966',
#   'Description': 'I have been grooming since 2014 and award winning competitive groomer since 2020. I take continuing education classes monthly and hold several certifications.',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(410) 544-5533'},
#  {'Zip': '20418',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20418',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20418',
#   'Name': 'Barnwellness Animal Care #A170',
#   'Description': 'A warm and cozy home grooming salon Servicing all breeds and sizes.',
#   'Address': '716 cloudyfold drive, Barnwellness Animal Care, Pikesville, MD 21208 United States',
#   'Website': 'http',
#   'Phone number': '(410) 269-3019'},
#  {'Zip': '20418',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20418',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20418',
#   'Name': "Poodles! / Puttin' on the Dog, Inc. #MD11",
#   'Description': 'National Certified Master Groomer with over 40 years experience providing limited mobile service for mannerly PUREBRED toy and miniature poodles (25 pound limit) in the Westminster, Md. area. Text ONLY 443-520-1721',
#   'Address': '1130 Old Westminster Rd, Westminster, MARYLAND (MD) 21157 United States of America',
#   'Website': '',
#   'Phone number': '(443) 520-1721'},
#  {'Zip': '20418',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20418',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20418',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20418',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20418',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20418',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20418',
#   'Name': 'Petsmart #MD37',
#   'Description': 'I have been grooming for 18 years and I love what I do.  I am always looking for opportunities to learn new techniques and expand my knowledge.',
#   'Address': '2601 Housley Rd, Annapolis, Maryland 21401 United States',
#   'Website': '',
#   'Phone number': '(410) 571-8646'},
#  {'Zip': '20418',
#   'Name': 'It’s a Pet Thing LLC #A966',
#   'Description': 'I have been grooming since 2014 and award winning competitive groomer since 2020. I take continuing education classes monthly and hold several certifications.',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(410) 544-5533'},
#  {'Zip': '20418',
#   'Name': 'Belquest Kennel & Cattery #N485',
#   'Description': '"Full service high quality grooming. grooming for Dogs & Cats since 1974',
#   'Address': '8220 Ritchie Hwy, Pasadena, MD 21122 United States',
#   'Website': 'https',
#   'Phone number': '(301) 831-7507'},
#  {'Zip': '20418',
#   'Name': 'The Barkershop #A421',
#   'Description': '100% crate free facility with 14 years experience.',
#   'Address': '3255 Jefferson Davis Highway, Suite 102, Stafford, VA 22554 United States',
#   'Website': 'http',
#   'Phone number': '(540) 402-4700'},
#  {'Zip': '20418',
#   'Name': 'Barnwellness Animal Care #A170',
#   'Description': 'A warm and cozy home grooming salon Servicing all breeds and sizes.',
#   'Address': '716 cloudyfold drive, Barnwellness Animal Care, Pikesville, MD 21208 United States',
#   'Website': 'http',
#   'Phone number': '(410) 269-3019'},
#  {'Zip': '20418',
#   'Name': 'Love the Dog!  Mobile Grooming Salon #VA147',
#   'Description': 'Linda is the owner and operator of Love the Dog! Mobile grooming salon.  She has been making dogs beautiful in the Warrenton Virginia area since 2007.',
#   'Address': '6423 Lancaster Drive, Warrenton, VA 20187 US',
#   'Website': 'http',
#   'Phone number': '(540) 295-1961'},
#  {'Zip': '20418',
#   'Name': 'Dirty Dog Wash & Salon #C613',
#   'Description': 'Dirty Dog Wash & Salon is a small boutique style salon located in Western Montgomery County, Maryland, just outside of Washington DC. We have been in business for almost 25 years. We have a well rounded staff who provide a very personalized, high level of service. We tailor every groom to fit each clients individual needs from puppies to senior dogs, all breeds and sizes. We love dogs and grooming them!',
#   'Address': '800 Trail Ave, Frederick, MD 21701 United States',
#   'Website': 'http',
#   'Phone number': '(301) 407-0326'},
#  {'Zip': '20418',
#   'Name': "Poodles! / Puttin' on the Dog, Inc. #MD11",
#   'Description': 'National Certified Master Groomer with over 40 years experience providing limited mobile service for mannerly PUREBRED toy and miniature poodles (25 pound limit) in the Westminster, Md. area. Text ONLY 443-520-1721',
#   'Address': '1130 Old Westminster Rd, Westminster, MARYLAND (MD) 21157 United States of America',
#   'Website': '',
#   'Phone number': '(443) 520-1721'},
#  {'Zip': '20419',
#   'Name': 'The Groomery on Glebe #D745',
#   'Description': '5 Star - Premier Dog & Cat Salon and Spa',
#   'Address': '226 W Glebe Rd, Alexandria, VA 22305 USA',
#   'Website': 'http',
#   'Phone number': '(703) 299-0299'},
#  {'Zip': '20419',
#   'Name': 'Pampered Pooches by Kimberlyn #C253',
#   'Description': 'I am a mobile groomer who loves what I do. I come to you.  Your pup is groomed in my van in front of your home.  I LOVE animals and absolutely LOOOVE Dogs. They are family and I treat them as if they are part of my family.',
#   'Address': '8107 Carey Branch Dr, Ft Washington, MD 20744 USA',
#   'Website': '',
#   'Phone number': '(301) 717-7801'},
#  {'Zip': '20419',
#   'Name': 'Pet Supplies Plus #C320',
#   'Description': 'I’ve been grooming for just about 11 years and am working towards being a certified NDGAA member. I work with a great small group of women who share their passion about furry family members.',
#   'Address': '7007 Manchester Blvd, Franconia, VA 22310 United States',
#   'Website': '',
#   'Phone number': '(703) 924-7246'},
#  {'Zip': '20419',
#   'Name': 'Featherle Pet Care #VA002',
#   'Description': '',
#   'Address': '13881 A- Metrotech Dr, Chantilly, VA 20151 USA',
#   'Website': 'http',
#   'Phone number': '(703) 378-9500'},
#  {'Zip': '20419',
#   'Name': 'The Pink Paw Spa #VA152',
#   'Description': 'I am a home based one on one salon with over 10 years of grooming experience.  I keep up to date with classes from master groomers all over the world. My goal is to make your dog look and feel amazing.',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(571) 989-3772'},
#  {'Zip': '20419',
#   'Name': 'Bark of the Town #MD18',
#   'Description': '"30 yeaars experience',
#   'Address': '1840 Strickland ct, Woodbridge, VA 22191 USA',
#   'Website': 'https',
#   'Phone number': '(301) 392-9663'},
#  {'Zip': '20419',
#   'Name': 'Petsmart #MD37',
#   'Description': 'I have been grooming for 18 years and I love what I do.  I am always looking for opportunities to learn new techniques and expand my knowledge.',
#   'Address': '2601 Housley Rd, Annapolis, Maryland 21401 United States',
#   'Website': '',
#   'Phone number': '(410) 571-8646'},
#  ...]

# %%
name_list = list()
del_index_list = list()
for idx, element in enumerate(processed_list):
    if element.get("Name") in name_list: del_index_list.append(idx)
    if element.get("Name"): name_list.append(element.get("Name"))
# for idx in del_index_list: processed_list.pop(idx)

# %%
cleand_list = list()
for idx, element in enumerate(processed_list):
    if not idx in del_index_list:
        cleand_list.append(element.copy())

# %%
processed = data.split("\n\n")
processed = [x.split("\n") for x in processed]
# proccesed_dict = dict()
# proessed_list = list()
rcds = dict()
processed_list = list()
count = 0
for x in processed:
    count+=1
#     if count==47:
#         break
    key, val = None, None
    cont_flag = False
    for y in x:
        if ":" in y:
            key = y.split(":")[0].strip()
            val = y.split(":")[1].strip()
            if val ==" Bark of the Town #MD18":
                print(f"COUNT: {count}")
            
        else:
            if val:
                cont_flag = True
                val + str(y.strip())
        if not cont_flag:
            rcds[key] = val.strip() if val else val
    if cont_flag:
        rcds[key] = val.strip() if val else val
    processed_list.append(rcds.copy())
# count = 0
# for idx, _ in enumerate(processed):
#     proessed_list.append({x.split(":")[0] : x.split(":")[1] for x in processed[idx]})
#     count += 1
name_list = list()
del_index_list = list()
for idx, element in enumerate(processed_list):
    if element.get("Name") in name_list: del_index_list.append(idx)
    if element.get("Name"): name_list.append(element.get("Name"))
# for idx in del_index_list: processed_list.pop(idx)  

cleand_list = list()
for idx, element in enumerate(processed_list):
    if not idx in del_index_list:
        cleand_list.append(element.copy())

# %%
len(name_list) - len(del_index_list)
# Out:
# 24

# %%
cleand_list
# Out:
# [{'Zip': '60002',
#   'Name': 'Elmbrook Veterinary Clinic and Grooming #WI07',
#   'Description': 'We offer one on one grooming in a calm environment located within a Veterinary Clinic.',
#   'Address': '150 N Janacek Rd, Brookfield, WI 53018 Waukesha',
#   'Website': 'http',
#   'Phone number': '(262) 786-7616'},
#  {'Zip': '60002',
#   'Name': 'Dognormous #IL20',
#   'Description': '"Dognormous is all about having a personal experience.  Our people have a large understanding of dogs, and they push themselves to continue to learn the world of dog.  We work hard to keep an holistic mind set by fulfilling mind, body, and puppy soul.',
#   'Address': '150 N Janacek Rd, Brookfield, WI 53018 Waukesha',
#   'Website': 'http',
#   'Phone number': '(262) 786-7616'},
#  {'Zip': '60918',
#   'Name': "Morgan's Place Canine Salon #N942",
#   'Description': 'Full service grooming in a home based environment for all breeds for over 12 years.  Specializes in schnauzers, golden retrievers and doodles of all varieties, using natural products with one on one attention for all pets',
#   'Address': '807 Chickory Dr, Champaign, IL 61822 USA',
#   'Website': 'http',
#   'Phone number': '(217) 390-2762',
#   None: None},
#  {'Zip': '61087',
#   'Name': 'Finer DeTails Pet Spa, #WI08',
#   'Description': '"Full service grooming and massage for canines and felines in a spa environment.',
#   'Address': '1034 College Ave, Wheaton, Illinois 60187 United States',
#   'Website': 'http',
#   'Phone number': '(608) 795-9837',
#   None: None},
#  {'Zip': '61810',
#   'Name': "Angela's Pet Spa, LLC #A754",
#   'Description': 'Grooming since 2004. AKC Safety Certified, pet Tech cpr Certified, certified Canine Esthetician, massage therapy, hand stripping, And numerous other classes both on line and in person, attended frequently. We are Mobile and salon based in Riley, Indiana.',
#   'Address': '7734 state rd 46, Riley, In 47871 United States',
#   'Website': 'http',
#   'Phone number': '(812) 308-3672',
#   None: None},
#  {'Zip': '62237',
#   'Name': "Jagger's Doggie Daycare #E545",
#   'Description': "Jagger's is a 1-stop shop for Dog Grooming, Boarding, Training, and Doggie Daycare.  We also have a Dog Bakery.  We offer a stress-free grooming experience with two different grooming personnel who provide personal, friendly service.  Our goal is always 100% customer satisfaction and customer communication is a top priority.  We offer grooming services ranging from Full Grooms to DeShed Baths and a variety of al a carte services.  Many of our customers drop off their dog for Daycare/Playtime and Socialization prior to their grooming experience.  This makes them very relaxed for their appointment and allows for flexibility in the schedule.  If you are going away for the weekend or a vacation trip,  Exit Baths are always an option when you board your dog with us.",
#   'Address': '414 Main Street, Mount Vernon, IL 62864 USA',
#   'Website': 'http',
#   'Phone number': '(618) 316-7021',
#   None: None},
#  {'Zip': '46012',
#   'Name': 'Animal Arts #IN28',
#   'Description': 'We are compassionate quality groomers dedicated to beautiful haircuts and a stress free environment.',
#   'Address': '1055 S. Rangeline Rd., Carmel, In 46932 Us',
#   'Website': '',
#   'Phone number': '(317) 575-1122',
#   None: None},
#  {'Zip': '46012',
#   'Name': 'The Pet Stylist LLC #IN23',
#   'Description': 'I have a small trailer on the safe side of my house that I have turned into a Mini grooming salon. It is very quiet and peaceful stress free. I groom most of my dogs wanted to time.  Over the years I found that it is a much better experience for the groomer as well as the pet with the one-on-one interaction.',
#   'Address': '8640 pleasant  creek ct  Indianapolis Indiana 46227 United States',
#   'Website': 'http',
#   'Phone number': '(317) 444-9403',
#   None: None},
#  {'Zip': '46012',
#   'Name': 'Just the Basics #IN43, C235',
#   'Description': 'Grooming, daycare and boarding of dogs, cats and pocket pets.',
#   'Address': '4903 S. High School Road, Suite B, Indianapolis, Indiana 46221 USA',
#   'Website': '',
#   'Phone number': '(317) 856-1100',
#   None: None},
#  {'Zip': '46068',
#   'Name': 'Glitter Grooming, LLC #C294',
#   'Description': 'We provide Grooming, Boarding, Doggy Daycare, and Mobile Grooming in and around the Fulton county area. Recently we added a Self Serve Dog Wash Station that is open 24/7,',
#   'Address': '2262 N. Old US Highway 31  Rochester IN 46975 United States',
#   'Website': '',
#   'Phone number': '(574) 847-7028',
#   None: None},
#  {'Zip': '46173',
#   'Name': 'Master’s Touch Pet Grooming #C349',
#   'Description': 'Alexis has been grooming for 5 years professionally. She has traveled to numerous dog shows and has been to a few NDGAA Workshops. She’s currently working to obtain her NCMG certification. In 2021, she decided to venture out on her own and start her own business. She has a true passion for pets. All pets are welcome! (including cats)',
#   'Address': '512 Main St., Hamilton, OH 45013 United States',
#   'Website': '',
#   'Phone number': '(513) 827-1801',
#   None: None},
#  {'Zip': '46304',
#   'Name': "Gordon's Grooming, #FL183",
#   'Description': "20+ years experience.  Hand stripping available.  Show grooming available.  Lara is also an open level grooming competitor.  Gordon's Grooming is also an AKC SAFE Certified Salon.  We groom by appointment so pets don't have to stay all day.",
#   'Address': '2159 N Oak Dr, Suite 1, Plymouth, Indiana 46563 United States',
#   'Website': 'http',
#   'Phone number': '(574) 612-3524',
#   None: None},
#  {'Zip': '46714',
#   'Name': 'dogs-R-us Styling Boutique #D594',
#   'Description': 'I have been grooming for 24 years and I am a graduate of Nash Academy of Animal Arts in Lexington, KY.  I have  owned my own business since 2005. We offer grooming of ALL breeds, daycare, and boarding. We also carry a full line of canine retail.',
#   'Address': '510 Clinton St, St. Marys, Ohio 45885 United States',
#   'Website': 'http',
#   'Phone number': '(419) 300-3647',
#   None: None},
#  {'Zip': '47018',
#   'Name': 'Fuzzy Butts LLC #OH73',
#   'Description': 'Angela has been grooming since 2000 when she attended Dayton Academy of Pet Grooming and graduated with a Certificate in pet grooming. She then attended in 2005 Ohio Academy of Pet Styling for advance hand scissoring classes and graduated with a Certificate. She then went to National Cat Groomers Institute of America and obtained her Certified Feline Master Groomer, certification She finally obtained her NCMG over the years as well.',
#   'Address': '3022 Harrison Avenue, Cincinnati, Ohio 45238 United States',
#   'Website': 'http',
#   'Phone number': '(513) 906-7115',
#   None: None},
#  {'Zip': '47018',
#   'Name': 'All Creatures Animal Hospital #D491',
#   'Description': '"Lauren Callahan is one of the groomers at our Amelia location, and she has been with our practice since March 2018. Lauren has worked exclusively in the grooming industry full-time since 2012.',
#   'Address': '512 Main St., Hamilton, OH 45013 United States',
#   'Website': '',
#   'Phone number': '(513) 827-1801',
#   None: None},
#  {'Zip': '47022',
#   'Name': 'Barkers Barbershop For Dogs #A451',
#   'Description': 'Barkers Barbershop For Dogs is an express grooming service. Owner, Hannah, believes in a holistic approach to grooming. We use all natural plant-based products and strive to provide a stress-free experience for both pet and owner.',
#   'Address': '28 E. Mulberry St., lebanon, OH 45036 United States',
#   'Website': 'http',
#   'Phone number': '(513) 836-3005',
#   None: None},
#  {'Zip': '47102',
#   'Name': 'SPaw for Dogs #IN48',
#   'Description': '"The Dog sPaw is pleased to offer quality and experienced services to all breeds of dogs.',
#   'Address': '28 E. Mulberry St., lebanon, OH 45036 United States',
#   'Website': 'http',
#   'Phone number': '(513) 836-3005',
#   None: None},
#  {'Zip': '47102',
#   'Name': 'K9 Design Mobile Pet Salon, LLC #E715',
#   'Description': 'We provide mobile grooming service to pets 35lbs & under.  Serving Shelbyville & Simpsonville Ky',
#   'Address': '3900 Buck Creek Rd, Finchville, KY 40022 USA',
#   'Website': '',
#   'Phone number': '(502) 921-3348',
#   None: None},
#  {'Zip': '51041',
#   'Name': 'Sioux Nation Pet clinic #B964',
#   'Description': 'I am a full service canine and feline groomer started grooming professionally in 2010',
#   'Address': '715 n Linda ave, Sioux falls, SD 57103 United States',
#   'Website': '',
#   'Phone number': '',
#   None: None},
#  {'Zip': '51608',
#   'Name': 'PETWEST #A478',
#   'Description': '"over 15 years',
#   'Address': '715 n Linda ave, Sioux falls, SD 57103 United States',
#   'Website': '',
#   'Phone number': '(852) 540-5823',
#   None: None},
#  {'Zip': '52590',
#   'Name': 'Pet Central #A643',
#   'Description': 'Full Service Dog & Cat Grooming of all sizes.',
#   'Address': '815 Main Street, Trenton, MO 64683 United States',
#   'Website': 'http',
#   'Phone number': '(660) 358-1291',
#   None: None},
#  {'Zip': '66002',
#   'Name': 'Professional Pet Grooming #KS11',
#   'Description': 'Barb offers mobile grooming to the Leavenworth Kansas area. She is very active in the pet grooming industry as a speaker and award winning author.  Barb is a National Certified Master Groomer',
#   'Address': 'Leavenworth, KA 66048',
#   'Website': 'http',
#   'Phone number': '(913) 682-1655',
#   None: None},
#  {'Zip': '66002',
#   'Name': 'Wizard of Paws Pet Grooming #A376',
#   'Description': '"Wizard of Paws was formerly known as From Bows to Toes and was based out of Monica’s house allowing her to be an at home mom because family is so important. The business started in Newton, Kansas in 1997, then to Basehor, Kansas in late 1997, where it remained until spring of 2000. Finally landing in Tonganoxie, our forever home. In 2011, we moved out of our home and into a retail pet store on 24-40, which closed its doors in 2012. From there, we found a spot at 612 E 4 th St. to start Wizard of Paws along with the pink poodle in the window.  You can find us at 406 E 4th St at our expanded location.',
#   'Address': 'Leavenworth, KA 66048',
#   'Website': 'http',
#   'Phone number': '(913) 682-1655',
#   None: None},
#  {'Zip': '66012',
#   'Name': "Messie Jessie's Mobile Grooming #MO18",
#   'Description': "I am a Nationally Certified Mobile Dog groomer just south of Kansas City, MO. I've been grooming for 17 years and of those I have owned my own mobile grooming business for 13. I offer a one on one experience, in a quiet and calm environment, with safe and clean handling.  I am experienced in all breed trims and hand scissoring. I am experienced with special needs, and elderly pets. Most appointments are finsihed in one hour. No cages, no interaction with other dogs, no waiting long periods, and no need to drive back and forth to your appointment. Simply provide me the dog at your home and I take care of everything else. My service is efficient, gentle, kind, and only use professional, quality products.",
#   'Address': '7812 lonnie ct, belton, MO 64012 United States',
#   'Website': 'http',
#   'Phone number': '(816) 682-6692',
#   None: None}]

# %%
len(cleand_list)
# Out:
# 24
